# %%
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.io as pio
import sklearn
import warnings
import sksurv.datasets
import numpy as np
from sksurv.metrics import concordance_index_censored

from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.exceptions import UndefinedMetricWarning
from sklearn import set_config
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.pipeline import make_pipeline
from sksurv.datasets import load_breast_cancer
from sksurv.linear_model import CoxnetSurvivalAnalysis, CoxPHSurvivalAnalysis
from sksurv.preprocessing import OneHotEncoder
from sksurv.util import Surv

warnings.filterwarnings("ignore", category=UndefinedMetricWarning)
set_config(display="text")  # displays text representation of estimators

# %%
df_meteo=pd.read_csv('https://projet-incendie.s3.eu-west-3.amazonaws.com/Param%C3%A8tres_API.csv', sep=';')
pd.set_option('display.max_rows', None)
display(df_meteo)
# Out:
#     Mnémonique                                            Libellé  \
# 0        BA300  HAUTEUR MINIMALE DE LA COUCHE >300M AVEC UNE N...
# 1         BROU               OCCURRENCE DE BROUILLARD QUOTIDIENNE
# 2        BRUME                    OCCURRENCE DE BRUME QUOTIDIENNE
# 3           DG                           DUREE DE GEL QUOTIDIENNE
# 4       DHUMEC                      DUREE HUMECTATION QUOTIDIENNE
# 5      DHUMI40                  DUREE HUMIDITE <= 40% QUOTIDIENNE
# 6      DHUMI80                  DUREE HUMIDITE >= 80% QUOTIDIENNE
# 7         DIFT                       RAYONNEMENT DIFFUS QUOTIDIEN
# 8         DIRT                       RAYONNEMENT DIRECT QUOTIDIEN
# 9          DRR              DUREE DES PRECIPITATIONS QUOTIDIENNES
# 10         DXI           DIRECTION VENT MAXI INSTANTANE QUOTIDIEN
# 11        DXI2  DIRECTION DU VENT INSTANTANE MAXI QUOTIDIEN A 2 M
# 12       DXI3S        DIRECTION DU VENT INSTANTANÉ SUR 3 SECONDES
# 13         DXY  DIRECTION VENT QUOTIDIEN MAXI MOYENNE SUR 10 MIN
# 14      ECLAIR                      OCCURRENCE ECLAIR QUOTIDIENNE
# 15   ETPGRILLE     ETP CALCULEE AU POINT DE GRILLE LE PLUS PROCHE
# 16      ETPMON           EVAPO-TRANSPIRATION MONTEITH QUOTIDIENNE
# 17        FF2M  MOYENNE DES VITESSES DU VENT A 2 METRES QUOTID...
# 18         FFM     MOYENNE DES VITESSES DU VENT A 10M QUOTIDIENNE
# 19       FUMEE                    OCCURRENCE DE FUMEE QUOTIDIENNE
# 20         FXI           VITESSE VENT MAXI INSTANTANE QUOTIDIENNE
# 21        FXI2    VITESSE DU VENT INSTANTANE MAXI QUOTIDIEN A 2 M
# 22       FXI3S  VITESSE DU VENT INSTANTANÉ SUR 3 SECONDES, MAX...
# 23         FXY    VITESSE VENT QUOTIDIEN MAXI MOYENNE SUR 10 MIN
# 24       GELEE                    OCCURRENCE DE GELEE QUOTIDIENNE
# 25        GLOT                       RAYONNEMENT GLOBAL QUOTIDIEN
# 26       GRELE                    OCCURRENCE DE GRELE QUOTIDIENNE
# 27      GRESIL                    OCCURENCE DE GRESIL QUOTIDIENNE
# 28     HNEIGEF                     HAUTEUR DE NEIGE TOMBEE EN 24H
# 29         HTN                  HEURE DU TN SOUS ABRI QUOTIDIENNE
# 30         HTX                  HEURE DU TX SOUS ABRI QUOTIDIENNE
# 31         HUN               HEURE DU MINI D'HUMIDITE QUOTIDIENNE
# 32         HUX               HEURE DU MAXI D'HUMIDITE QUOTIDIENNE
# 33         HXI               HEURE VENT MAXI INSTANTANE QUOTIDIEN
# 34        HXI2     HEURE DU VENT MAX INSTANTANE A 2 M QUOTIDIENNE
# 35       HXI3S            HEURE DU VENT INSTANTANÉ SUR 3 SECONDES
# 36         HXY      HEURE VENT QUOTIDIEN MAXI MOYENNE SUR 10 MIN
# 37     INFRART                  SOMME DES RAYONNEMENTS IR HORAIRE
# 38        INST                     DUREE D'INSOLATION QUOTIDIENNE
# 39       NB300     NÉBULOSITÉ MAXIMALE > 4/8 D’UNE COUCHE < 300 M
# 40        NEIG                    OCCURRENCE DE NEIGE QUOTIDIENNE
# 41  NEIGETOT06        EPAISSEUR DE NEIGE TOTALE RELEVEE A 0600 FU
# 42   NEIGETOTX  MAXIMUM QUOTIDIEN DES EPAISSEURS DE NEIGE TOTA...
# 43        ORAG                     OCCURRENCE D'ORAGE QUOTIDIENNE
# 44       PMERM                   PRESSION MER MOYENNE QUOTIDIENNE
# 45     PMERMIN                   PRESSION MER MINIMUM QUOTIDIENNE
# 46       ROSEE                    OCCURRENCE DE ROSEE QUOTIDIENNE
# 47          RR              HAUTEUR DE PRECIPITATIONS QUOTIDIENNE
# 48       SIGMA                       RAPPORT INSOLATION QUOTIDIEN
# 49    SOLNEIGE                 OCCURRENCE DE SOL COUVERT DE NEIGE
# 50      TAMPLI                 AMPLITUDE ENTRE TN ET TX QUOTIDIEN
# 51          TM          TEMPERATURE MOYENNE SOUS ABRI QUOTIDIENNE
# 52     TMERMAX   TEMPERATURE MAXIMALE QUOTIDIENNE DE L'EAU DE MER
# 53     TMERMIN   TEMPERATURE MINIMALE QUOTIDIENNE DE L'EAU DE MER
# 54        TMNX  TEMPERATURE MOYENNE SOUS ABRI QUOTIDIENNE A PA...
# 55          TN         TEMPERATURE MINIMALE SOUS ABRI QUOTIDIENNE
# 56        TN50               TEMPERATURE MINI A +50CM QUOTIDIENNE
# 57       TNSOL           TEMPERATURE MINIMALE A +10CM QUOTIDIENNE
# 58       TNTXM                      MOYENNE DE TN ET TX QUOTIDIEN
# 59        TSVM              TENSION DE VAPEUR MOYENNE QUOTIDIENNE
# 60          TX         TEMPERATURE MAXIMALE SOUS ABRI QUOTIDIENNE
# 61          UM                          HUMIDITE RELATIVE MOYENNE
# 62          UN             HUMIDITE RELATIVE MINIMALE QUOTIDIENNE
# 63          UV                 RAYONNEMENT ULTRA VIOLET QUOTIDIEN
# 64  UV_INDICEX                         MAX DES INDICES UV HORAIRE
# 65          UX             HUMIDITE RELATIVE MAXIMALE QUOTIDIENNE
# 66     VERGLAS                              OCCURRENCE DE VERGLAS
#
#                   Unité Pas de temps
# 0                METRES    quotidien
# 1               BOOLEEN    quotidien
# 2               BOOLEEN    quotidien
# 3               MINUTES    quotidien
# 4               MINUTES    quotidien
# 5               MINUTES    quotidien
# 6               MINUTES    quotidien
# 7            JOULES/CM2    quotidien
# 8            JOULES/CM2    quotidien
# 9               MINUTES    quotidien
# 10          ROSE DE 360    quotidien
# 11          ROSE DE 360    quotidien
# 12          ROSE DE 360    quotidien
# 13          ROSE DE 360    quotidien
# 14              BOOLEEN    quotidien
# 15  MILLIMETRES ET 1/10    quotidien
# 16  MILLIMETRES ET 1/10    quotidien
# 17          M/S ET 1/10    quotidien
# 18          M/S ET 1/10    quotidien
# 19              BOOLEEN    quotidien
# 20          M/S ET 1/10    quotidien
# 21          M/S ET 1/10    quotidien
# 22          M/S ET 1/10    quotidien
# 23          M/S ET 1/10    quotidien
# 24              BOOLEEN    quotidien
# 25           JOULES/CM2    quotidien
# 26              BOOLEEN    quotidien
# 27              BOOLEEN    quotidien
# 28          CENTIMETRES    quotidien
# 29    HEURES ET MINUTES    quotidien
# 30    HEURES ET MINUTES    quotidien
# 31    HEURES ET MINUTES    quotidien
# 32    HEURES ET MINUTES    quotidien
# 33    HEURES ET MINUTES    quotidien
# 34    HEURES ET MINUTES    quotidien
# 35    HEURES ET MINUTES    quotidien
# 36    HEURES ET MINUTES    quotidien
# 37           JOULES/CM2    quotidien
# 38              MINUTES    quotidien
# 39                OCTAS    quotidien
# 40              BOOLEEN    quotidien
# 41           CENTIMETRE    quotidien
# 42           CENTIMETRE    quotidien
# 43              BOOLEEN    quotidien
# 44          HPA ET 1/10    quotidien
# 45          HPA ET 1/10    quotidien
# 46              BOOLEEN    quotidien
# 47  MILLIMETRES ET 1/10    quotidien
# 48                    %    quotidien
# 49              BOOLEEN    quotidien
# 50        DEG C ET 1/10    quotidien
# 51        DEG C ET 1/10    quotidien
# 52        DEG C ET 1/10    quotidien
# 53        DEG C ET 1/10    quotidien
# 54        DEG C ET 1/10    quotidien
# 55        DEG C ET 1/10    quotidien
# 56        DEG C ET 1/10    quotidien
# 57        DEG C ET 1/10    quotidien
# 58        DEG C ET 1/10    quotidien
# 59          HPA ET 1/10    quotidien
# 60        DEG C ET 1/10    quotidien
# 61                    %    quotidien
# 62                    %    quotidien
# 63           JOULES/CM2    quotidien
# 64                         quotidien
# 65                    %    quotidien
# 66              BOOLEEN    quotidien

# %%
df_corse=pd.read_csv('dataset_modele_decompte.csv', sep=';')

pd.set_option('display.max_columns', None)
df_corse.head(10)
# Out:
#     RR  DRR    TN  HTN    TX  HTX  TM   TMNX  TNSOL  TN50  TAMPLI  TNTXM  FFM  \
# 0  0.0  NaN  10.8  NaN  22.2  NaN NaN  16.50    NaN   NaN    11.4   16.5  NaN
# 1  0.5  NaN  11.9  NaN  20.2  NaN NaN  16.05    NaN   NaN     8.3   16.1  NaN
# 2  8.2  NaN  10.9  NaN  19.0  NaN NaN  14.95    NaN   NaN     8.1   15.0  NaN
# 3  0.0  NaN  11.3  NaN  17.2  NaN NaN  14.25    NaN   NaN     5.9   14.3  NaN
# 4  0.4  NaN  13.1  NaN  20.6  NaN NaN  16.85    NaN   NaN     7.5   16.9  NaN
# 5  0.2  NaN   9.9  NaN  18.6  NaN NaN  14.25    NaN   NaN     8.7   14.3  NaN
# 6  0.2  NaN   9.8  NaN  21.2  NaN NaN  15.50    NaN   NaN    11.4   15.5  NaN
# 7  0.0  NaN  11.1  NaN  18.5  NaN NaN  14.80    NaN   NaN     7.4   14.8  NaN
# 8  0.0  NaN   9.1  NaN  19.8  NaN NaN  14.45    NaN   NaN    10.7   14.5  NaN
# 9  3.4  NaN  10.8  NaN  20.9  NaN NaN  15.85    NaN   NaN    10.1   15.9  NaN
#
#    FXI  DXI  HXI  FXY  DXY  HXY  FXI3S  HXI3S  UN  HUN  UX  HUX  DHUMI40  \
# 0  NaN  NaN  NaN  NaN  NaN  NaN    NaN    NaN NaN  NaN NaN  NaN      NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN    NaN    NaN NaN  NaN NaN  NaN      NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN    NaN    NaN NaN  NaN NaN  NaN      NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN    NaN    NaN NaN  NaN NaN  NaN      NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN    NaN    NaN NaN  NaN NaN  NaN      NaN
# 5  NaN  NaN  NaN  NaN  NaN  NaN    NaN    NaN NaN  NaN NaN  NaN      NaN
# 6  NaN  NaN  NaN  NaN  NaN  NaN    NaN    NaN NaN  NaN NaN  NaN      NaN
# 7  NaN  NaN  NaN  NaN  NaN  NaN    NaN    NaN NaN  NaN NaN  NaN      NaN
# 8  NaN  NaN  NaN  NaN  NaN  NaN    NaN    NaN NaN  NaN NaN  NaN      NaN
# 9  NaN  NaN  NaN  NaN  NaN  NaN    NaN    NaN NaN  NaN NaN  NaN      NaN
#
#    DHUMI80  TSVM  UM  ORAG  BRUME  ETPMON  ETPGRILLE  Code INSEE_x  \
# 0      NaN   NaN NaN   NaN    NaN     NaN        NaN       20004.0
# 1      NaN   NaN NaN   NaN    NaN     NaN        NaN       20004.0
# 2      NaN   NaN NaN   NaN    NaN     NaN        NaN       20004.0
# 3      NaN   NaN NaN   NaN    NaN     NaN        NaN       20004.0
# 4      NaN   NaN NaN   NaN    NaN     NaN        NaN       20004.0
# 5      NaN   NaN NaN   NaN    NaN     NaN        NaN       20004.0
# 6      NaN   NaN NaN   NaN    NaN     NaN        NaN       20004.0
# 7      NaN   NaN NaN   NaN    NaN     NaN        NaN       20004.0
# 8      NaN   NaN NaN   NaN    NaN     NaN        NaN       20004.0
# 9      NaN   NaN NaN   NaN    NaN     NaN        NaN       20004.0
#
#    Code Postal  moyenne precipitations année  moyenne precipitations mois  \
# 0        20000                          2.80                         0.56
# 1        20000                          2.80                         0.55
# 2        20000                          2.80                         0.55
# 3        20000                          2.82                         0.55
# 4        20000                          2.82                         0.55
# 5        20000                          2.82                         0.56
# 6        20000                          2.82                         0.55
# 7        20000                          2.82                         0.52
# 8        20000                          2.82                         0.55
# 9        20000                          2.82                         1.32
#
#    moyenne evapotranspiration année  moyenne evapotranspiration mois  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
# 5                               NaN                              NaN
# 6                               NaN                              NaN
# 7                               NaN                              NaN
# 8                               NaN                              NaN
# 9                               NaN                              NaN
#
#    moyenne vitesse vent année  moyenne vitesse vent mois  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# 5                         NaN                        NaN
# 6                         NaN                        NaN
# 7                         NaN                        NaN
# 8                         NaN                        NaN
# 9                         NaN                        NaN
#
#    moyenne temperature année  moyenne temperature mois  \
# 0                      11.43                     10.19
# 1                      11.41                     10.24
# 2                      11.41                     10.38
# 3                      11.40                     10.32
# 4                      11.40                     10.26
# 5                      11.38                     10.20
# 6                      11.37                     10.17
# 7                      11.36                     10.15
# 8                      11.35                     10.31
# 9                      11.35                     10.59
#
#    Surface parcourue (m2)  Surface forêt (m2)  Surface maquis garrigues (m2)  \
# 0                     NaN                 NaN                            NaN
# 1                     NaN                 NaN                            NaN
# 2                     NaN                 NaN                            NaN
# 3                     NaN                 NaN                            NaN
# 4                     NaN                 NaN                            NaN
# 5                     NaN                 NaN                            NaN
# 6                     NaN                 NaN                            NaN
# 7                     NaN                 NaN                            NaN
# 8                     NaN                 NaN                            NaN
# 9                     NaN                 NaN                            NaN
#
#    Autres surfaces naturelles hors forêt (m2)  Surfaces agricoles (m2)  \
# 0                                         NaN                      NaN
# 1                                         NaN                      NaN
# 2                                         NaN                      NaN
# 3                                         NaN                      NaN
# 4                                         NaN                      NaN
# 5                                         NaN                      NaN
# 6                                         NaN                      NaN
# 7                                         NaN                      NaN
# 8                                         NaN                      NaN
# 9                                         NaN                      NaN
#
#    Autres surfaces (m2)  Surface autres terres boisées (m2)  \
# 0                   NaN                                 NaN
# 1                   NaN                                 NaN
# 2                   NaN                                 NaN
# 3                   NaN                                 NaN
# 4                   NaN                                 NaN
# 5                   NaN                                 NaN
# 6                   NaN                                 NaN
# 7                   NaN                                 NaN
# 8                   NaN                                 NaN
# 9                   NaN                                 NaN
#
#    Surfaces non boisées naturelles (m2)  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
#
#    Surfaces non boisées artificialisées (m2)  Surfaces non boisées (m2)  \
# 0                                        NaN                        NaN
# 1                                        NaN                        NaN
# 2                                        NaN                        NaN
# 3                                        NaN                        NaN
# 4                                        NaN                        NaN
# 5                                        NaN                        NaN
# 6                                        NaN                        NaN
# 7                                        NaN                        NaN
# 8                                        NaN                        NaN
# 9                                        NaN                        NaN
#
#    Type de peuplement Nature  Feux geo_point_2d    ville        Date  \
# 0                 NaN    NaN     0          NaN  Ajaccio  2014-04-25
# 1                 NaN    NaN     0          NaN  Ajaccio  2014-04-26
# 2                 NaN    NaN     0          NaN  Ajaccio  2014-04-27
# 3                 NaN    NaN     0          NaN  Ajaccio  2014-04-28
# 4                 NaN    NaN     0          NaN  Ajaccio  2014-04-29
# 5                 NaN    NaN     0          NaN  Ajaccio  2014-04-30
# 6                 NaN    NaN     0          NaN  Ajaccio  2014-05-01
# 7                 NaN    NaN     0          NaN  Ajaccio  2014-05-02
# 8                 NaN    NaN     0          NaN  Ajaccio  2014-05-03
# 9                 NaN    NaN     0          NaN  Ajaccio  2014-05-04
#
#    décompte   latitude  longitude  évènement  Feu prévu
# 0      19.0  41.926399   8.737603      False          1
# 1      18.0  41.926399   8.737603      False          1
# 2      17.0  41.926399   8.737603      False          1
# 3      16.0  41.926399   8.737603      False          1
# 4      15.0  41.926399   8.737603      False          1
# 5      14.0  41.926399   8.737603      False          1
# 6      13.0  41.926399   8.737603      False          1
# 7      12.0  41.926399   8.737603      False          1
# 8      11.0  41.926399   8.737603      False          1
# 9      10.0  41.926399   8.737603      False          1

# %%
df_corse['Feux'].value_counts()
# Out:
# Feux
# 0    268294
# 1      5251
# Name: count, dtype: int64

# %%
df_corse.shape
# Out:
# (273545, 64)

# %%
pd.set_option('display.max_rows', None)
df_corse.isnull().sum()/len(df_corse)*100
# Out:
# RR                                             10.215504
# DRR                                            93.894972
# TN                                             16.173207
# HTN                                            32.841032
# TX                                             16.213055
# HTX                                            32.832258
# TM                                             30.399751
# TMNX                                           16.408635
# TNSOL                                          90.287521
# TN50                                           90.276189
# TAMPLI                                         16.408635
# TNTXM                                          16.408635
# FFM                                            47.274489
# FXI                                            48.657077
# DXI                                            48.730922
# HXI                                            49.401013
# FXY                                            52.537243
# DXY                                            52.571606
# HXY                                            52.601217
# FXI3S                                          72.868084
# HXI3S                                          73.030763
# UN                                             49.800581
# HUN                                            49.955583
# UX                                             49.803871
# HUX                                            49.980076
# DHUMI40                                        50.332121
# DHUMI80                                        50.419127
# TSVM                                           47.800545
# UM                                             47.738763
# ORAG                                           80.770623
# BRUME                                          80.298306
# ETPMON                                         90.762032
# ETPGRILLE                                      31.911751
# Code INSEE_x                                    0.000000
# Code Postal                                     0.000000
# moyenne precipitations année                   16.212323
# moyenne precipitations mois                    11.058144
# moyenne evapotranspiration année               91.429198
# moyenne evapotranspiration mois                90.816867
# moyenne vitesse vent année                     67.257307
# moyenne vitesse vent mois                      50.273995
# moyenne temperature année                      25.010510
# moyenne temperature mois                       17.755031
# Surface parcourue (m2)                         98.080389
# Surface forêt (m2)                             99.165037
# Surface maquis garrigues (m2)                  98.741706
# Autres surfaces naturelles hors forêt (m2)     99.857062
# Surfaces agricoles (m2)                        99.857062
# Autres surfaces (m2)                           99.857062
# Surface autres terres boisées (m2)            100.000000
# Surfaces non boisées naturelles (m2)          100.000000
# Surfaces non boisées artificialisées (m2)     100.000000
# Surfaces non boisées (m2)                      99.331371
# Type de peuplement                             99.035259
# Nature                                         98.973843
# Feux                                            0.000000
# geo_point_2d                                   98.080389
# ville                                           0.000000
# Date                                            0.000000
# décompte                                       11.936610
# latitude                                        0.000000
# longitude                                       0.000000
# évènement                                       0.000000
# Feu prévu                                       0.000000
# dtype: float64

# %%
df_corse['Date'] = pd.to_datetime(df_corse['Date'])
df_corse['Année'] = df_corse['Date'].dt.year
df_corse['Mois'] = df_corse['Date'].dt.month

# Calculer le nombre de feux par an pour chaque code postal
df_corse['Nombre de feu par an']= df_corse.groupby(['Code Postal', 'Année'])['Feux'].transform('sum')
df_corse['Nombre de feu par mois']= df_corse.groupby(['Code Postal', 'Année', 'Mois'])['Feux'].transform('sum')

# %% [markdown]
# #### Modèle MVP

# %%
# 1. Supprimer les colonnes avec trop de NaN (> 50% par exemple)
threshold = 0.5
cols_to_keep = df_corse.columns[df_corse.isnull().mean() < threshold]
df_clean = df_corse[cols_to_keep].copy()
df_clean['Feu prévu'] = df_clean['Feu prévu'].astype(bool)  # Assurez-vous que 'Feux prévu' est de type float

# 2. Sélectionner uniquement les colonnes numériques nécessaires pour le modèle (ici à adapter)
features = [
    "RR", "TN", "TX", "TM", "UM", "ETPGRILLE", "ETPMON",
    "moyenne precipitations année", "moyenne precipitations mois",
    "moyenne evapotranspiration année", "moyenne evapotranspiration mois",
    "moyenne vitesse vent année", "moyenne vitesse vent mois",
    "moyenne temperature année", "moyenne temperature mois","Nombre de feu par an","Nombre de feu par mois"
]
# Ne garder que les features existantes dans df_clean (évite erreur si colonne supprimée)
features = [f for f in features if f in df_clean.columns]

# 3. Retirer les lignes où y ("évènement" et "décompte") est manquant
df_clean = df_clean.dropna(subset=["Feu prévu", "décompte"])

# 4. Extraire X et y
X = df_clean[features]
y = Surv.from_dataframe("Feu prévu", "décompte", df_clean)

# 5. Pipeline avec SimpleImputer pour remplacer les NaN restants par la médiane
pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy="median")),
    ("coxnet", CoxnetSurvivalAnalysis(l1_ratio=0.9, alpha_min_ratio=0.05))
])

# param_grid = {
#     "coxnet__l1_ratio": [0.1, 0.5, 0.9],
#     "coxnet__alpha_min_ratio": [0.01, 0.05]
# }
# # === Cross-validation ===
# cv = KFold(n_splits=5, shuffle=True, random_state=42)

# # === Grid Search avec scoring basé sur le c-index ===
# def c_index_scorer(estimator, X_val, y_val):
#     predictions = estimator.predict(X_val)
#     result = concordance_index_censored(y_val["Feu prévu"], y_val["décompte"], predictions)
#     return result[0]

# grid = GridSearchCV(
#     pipeline,
#     param_grid=param_grid,
#     scoring=c_index_scorer,
#     cv=cv,
#     n_jobs=-1
# )

# # === Entraînement ===
# grid.fit(X, y)

# # === Meilleur modèle ===
# best_model = grid.best_estimator_
# print("Meilleurs hyperparamètres :", grid.best_params_)

# # === Prédictions ===
# df_clean["risque_feu"] = best_model.predict(X)

# 6. Fit du modèle
pipeline.fit(X, y)

# 7. Vérifier qu'il n'y a plus de NaN dans X imputé (optionnel)
X_imputed = pipeline.named_steps["imputer"].transform(X)
print(f"Nombre de NaN après imputation: {np.isnan(X_imputed).sum()}")
risque = pipeline.predict(X)

df_clean["risque_feu"] = risque
# Out:
# Nombre de NaN après imputation: 0

# %%
df_clean.shape
# Out:
# (240893, 39)

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df_clean['risque_feu'], bins=50, kde=True)
plt.title("Distribution des scores de risque de feu")
plt.xlabel("Score de risque")
plt.ylabel("Fréquence")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x=df_clean["risque_feu"])
plt.title("Distribution des scores de risque de feu")
plt.xlabel("Score de risque")
plt.show()

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 240893 entries, 0 to 273544
# Data columns (total 39 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   RR                            214993 non-null  float64
#  1   TN                            199074 non-null  float64
#  2   HTN                           157570 non-null  float64
#  3   TX                            198978 non-null  float64
#  4   HTX                           157592 non-null  float64
#  5   TM                            164043 non-null  float64
#  6   TMNX                          198444 non-null  float64
#  7   TAMPLI                        198444 non-null  float64
#  8   TNTXM                         198444 non-null  float64
#  9   FFM                           128785 non-null  float64
#  10  FXI                           124968 non-null  float64
#  11  DXI                           124809 non-null  float64
#  12  HXI                           123097 non-null  float64
#  13  UN                            122511 non-null  float64
#  14  HUN                           122198 non-null  float64
#  15  UX                            122502 non-null  float64
#  16  HUX                           122136 non-null  float64
#  17  TSVM                          127986 non-null  float64
#  18  UM                            128106 non-null  float64
#  19  ETPGRILLE                     160240 non-null  float64
#  20  Code INSEE_x                  240893 non-null  float64
#  21  Code Postal                   240893 non-null  int64
#  22  moyenne precipitations année  202692 non-null  float64
#  23  moyenne precipitations mois   213141 non-null  float64
#  24  moyenne temperature année     179902 non-null  float64
#  25  moyenne temperature mois      195342 non-null  float64
#  26  Feux                          240893 non-null  int64
#  27  ville                         240893 non-null  object
#  28  Date                          240893 non-null  datetime64[ns]
#  29  décompte                      240893 non-null  float64
#  30  latitude                      240893 non-null  float64
#  31  longitude                     240893 non-null  float64
#  32  évènement                     240893 non-null  bool
#  33  Feu prévu                     240893 non-null  bool
#  34  Année                         240893 non-null  int32
#  35  Mois                          240893 non-null  int32
#  36  Nombre de feu par an          240893 non-null  int64
#  37  Nombre de feu par mois        240893 non-null  int64
#  38  risque_feu                    240893 non-null  float64
# dtypes: bool(2), datetime64[ns](1), float64(29), int32(2), int64(4), object(1)
# memory usage: 68.5+ MB

# %%
fig = px.scatter_map(
    df_clean,
    lat="latitude",
    lon="longitude",
    hover_name="ville",
    hover_data={"risque_feu": True},
    color="risque_feu",  # Couleur continue basée sur le score
    # range_color=[0, 1],  # Ajuster la plage de couleurs
    color_continuous_scale=["green", "yellow", "red"],  # Dégradé du bleu au rouge
    zoom=7,
    height=800,
)

fig.update_layout(
    mapbox_style="open-street-map",
    title="Carte du risque de feu - Dégradé de couleurs",
    margin={"r": 0, "t": 40, "l": 0, "b": 0},
    coloraxis_showscale=False
)
fig.show()
fig.write_html("carte_risque_feu_degrade.html")

# %% [markdown]
# ### Modele predict survival fonction

# %%
X = SimpleImputer(strategy="median").fit_transform(X)
estimator = CoxnetSurvivalAnalysis(l1_ratio=0.99, fit_baseline_model=True)
estimator.fit(X, y)

X_df = pd.DataFrame(X, columns=[f'feature_{i}' for i in range(X.shape[1])])
surv_funcs = {}
for alpha in estimator.alphas_[:5]:
    print(f"Shape of X_df.iloc[:1]: {X_df.iloc[:1].shape}")
    surv_funcs[alpha] = estimator.predict_survival_function(
        X_df.iloc[:1], alpha=alpha)

for alpha, surv_alpha in surv_funcs.items():
     for fn in surv_alpha:
         plt.step(fn.x, fn(fn.x), where="post",
                  label=f"alpha = {alpha:.3f}")

plt.ylim(0, 1)
plt.legend()
plt.show()
# Out:
# Shape of X_df.iloc[:1]: (1, 12)
# Shape of X_df.iloc[:1]: (1, 12)
# Shape of X_df.iloc[:1]: (1, 12)
# Shape of X_df.iloc[:1]: (1, 12)
# Shape of X_df.iloc[:1]: (1, 12)
# c:\Users\m_bar\Incendie\.venv\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning:
#
# X has feature names, but CoxnetSurvivalAnalysis was fitted without feature names
#
# c:\Users\m_bar\Incendie\.venv\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning:
#
# X has feature names, but CoxnetSurvivalAnalysis was fitted without feature names
#
# c:\Users\m_bar\Incendie\.venv\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning:
#
# X has feature names, but CoxnetSurvivalAnalysis was fitted without feature names
#
# c:\Users\m_bar\Incendie\.venv\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning:
#
# X has feature names, but CoxnetSurvivalAnalysis was fitted without feature names
#
# c:\Users\m_bar\Incendie\.venv\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning:
#
# X has feature names, but CoxnetSurvivalAnalysis was fitted without feature names

# %%
# # Metric de concordance
# name_event = df_clean['Feu prévu'] 
# name_time = df_clean['décompte']
# # Fonction pour calculer le score de concordance
# def score(estimator, X, y):
#     """Returns the concordance index of the prediction."""
#     name_event, name_time = y.dtype.names
#     risk_score = estimator.predict(X)
#     if not getattr(estimator, "_predict_risk_score", True):
#         risk_score *= -1  # convert prediction on time scale to risk scale
#     result = concordance_index_censored(y[name_event], y[name_time], risk_score)
#     return result[0]

# # Calcul du score de concordance
# cindex = score(estimator, X, y)
# print(f"Concordance Index: {cindex}")

# %%
# Étape 1 : prédire les fonctions de survie sur tout X
surv_funcs = estimator.predict_survival_function(X)

# Étape 2 : évaluer S(t) à t = 365 jours (exemple)
# t = 365  # Durée en jours pour l'évaluation
durees = [90, 180, 365]  # ou autre valeur de durée
df_plot = df_clean.copy()
# risques = [1 - fn(t) if t in fn.x else 1 - fn(fn.x[-1]) for fn in surv_funcs]
for t in durees:
    risques = []
    for fn in surv_funcs:
        # Si t dépasse la durée max connue de la fonction, on prend la dernière valeur
        if t in fn.x:
            risques.append(1 - fn(t))
        else:
            risques.append(1 - fn(fn.x[-1]))
    df_plot[f"risque_{t}j"] = risques
# Étape 3 : créer un DataFrame avec les positions
# df_plot = df_clean.copy()
# df_plot["risque_365j"] = risques

# Étape 4 : afficher avec plotly (attention aux noms de colonnes)
fig = px.scatter_map(
    df_plot,
    lat="latitude",
    lon="longitude",
    color="risque_90j",
    # color="risque_365j",
    color_continuous_scale="YlOrRd",
    hover_name="ville",
    hover_data={"risque_90j": True},
    # hover_data={"risque_365j": True},
    zoom=7,
    height=800
)

fig.update_layout(
    mapbox_style="open-street-map",
    title="Risque estimé selon la durée (jours)",
    margin={"r": 0, "t": 40, "l": 0, "b": 0},
    updatemenus=[
        dict(
            type="dropdown",
            direction="down",
            buttons=[
                dict(label="90 jours", method="restyle", args=[{"marker.color": [df_plot["risque_90j"]]}]),
                dict(label="180 jours", method="restyle", args=[{"marker.color": [df_plot["risque_180j"]]}]),
                dict(label="365 jours", method="restyle", args=[{"marker.color": [df_plot["risque_365j"]]}])
            ],
            pad={"r": 10, "t": 10},
            showactive=True,
            x=0.05,
            xanchor="left",
            y=1.1,
            yanchor="top"
        )
    ]
)

fig.show()

# fig.update_layout(
#     mapbox_style="open-street-map",
#     title="Risque estimé à 365 jours par commune",
#     margin={"r": 0, "t": 40, "l": 0, "b": 0}
# )

# fig.show()
